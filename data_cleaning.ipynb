# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import seaborn as sns
from random import randrange
from scipy.stats import linregress
# Study data files
path = "Resources/backloggd_games.csv"

# Read the mouse data and the study results
game_df = pd.read_csv(path)

# Display the data table for preview
game_df.head()
# Out:
#    Unnamed: 0                                    Title  Release_Date  \
# 0           0                               Elden Ring  Feb 25, 2022
# 1           1  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2           2                                    Hades  Dec 07, 2018
# 3           3                            Hollow Knight  Feb 24, 2017
# 4           4                                Undertale  Sep 15, 2015
#
#                                           Developers  \
# 0     ['FromSoftware', 'Bandai Namco Entertainment']
# 1  ['Nintendo', 'Nintendo EPD Production Group No...
# 2                               ['Supergiant Games']
# 3                                    ['Team Cherry']
# 4                                 ['tobyfox', '8-4']
#
#                                              Summary  \
# 0  Elden Ring is a fantasy, action and open world...
# 1  The Legend of Zelda: Breath of the Wild is the...
# 2  A rogue-lite hack and slash dungeon crawler in...
# 3  A 2D metroidvania with an emphasis on close co...
# 4  A small child falls into the Underground, wher...
#
#                                            Platforms  \
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 1                       ['Wii U', 'Nintendo Switch']
# 2  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 3  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch']
# 4  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'...
#
#                                               Genres  Rating Plays Playing  \
# 0                               ['Adventure', 'RPG']     4.5   21K    4.1K
# 1                            ['Adventure', 'Puzzle']     4.4   35K    3.1K
# 2           ['Adventure', 'Brawler', 'Indie', 'RPG']     4.3   25K    3.5K
# 3                 ['Adventure', 'Indie', 'Platform']     4.4   25K    2.7K
# 4  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...     4.2   32K     728
#
#   Backlogs Wishlist Lists Reviews
# 0     5.6K     5.5K  4.6K      3K
# 1     5.6K       3K  5.1K      3K
# 2     7.3K       4K  3.2K    2.1K
# 3     9.6K     2.6K  3.4K    2.1K
# 4     5.7K     2.1K  3.9K    2.5K

# %%
game_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    60000 non-null  int64
#  1   Title         60000 non-null  object
#  2   Release_Date  60000 non-null  object
#  3   Developers    60000 non-null  object
#  4   Summary       55046 non-null  object
#  5   Platforms     60000 non-null  object
#  6   Genres        60000 non-null  object
#  7   Rating        25405 non-null  float64
#  8   Plays         60000 non-null  object
#  9   Playing       60000 non-null  object
#  10  Backlogs      60000 non-null  object
#  11  Wishlist      60000 non-null  object
#  12  Lists         60000 non-null  object
#  13  Reviews       60000 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 6.4+ MB

# %%
game_df.Developers.nunique()
# Out:
# 18356

# %%
game_df.Developers.value_counts()
# Out:
# Developers
# []                                        18091
# ['Konami']                                  470
# ['Nintendo']                                325
# ['Capcom']                                  318
# ['Sega']                                    185
#                                           ...
# ['NanoPiko Games', 'Plug In Digital']         1
# ['DevCubeStudio', 'Fibrum Limited']           1
# ['TeamFatBears']                              1
# ['Blueside', 'Microsoft Game Studios']        1
# ['Travian Games', 'Shadow Masters']           1
# Name: count, Length: 18356, dtype: int64

# %%
game_df.Title.value_counts()
# Out:
# Title
# Date A Live Twin Edition: Rio Reincarnation            24
# Tube                                                   21
# Yakiniku Bugyou                                        20
# The Store is Closed                                    20
# Nonogram Survival                                      19
#                                                        ..
# Spider-Man: Homecoming - Virtual Reality Experience     1
# Hammerfight                                             1
# Team USA Basketball                                     1
# Syvalion                                                1
# Orbit - Playing with Gravity                            1
# Name: count, Length: 40985, dtype: int64

# %%
game_df.Title.nunique()
# Out:
# 40985

# %%
game_df['Developers']=game_df['Developers'].str.split(',').str[0]
game_df.head()
# Out:
#    Unnamed: 0                                    Title  Release_Date  \
# 0           0                               Elden Ring  Feb 25, 2022
# 1           1  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2           2                                    Hades  Dec 07, 2018
# 3           3                            Hollow Knight  Feb 24, 2017
# 4           4                                Undertale  Sep 15, 2015
#
#              Developers                                            Summary  \
# 0       ['FromSoftware'  Elden Ring is a fantasy, action and open world...
# 1           ['Nintendo'  The Legend of Zelda: Breath of the Wild is the...
# 2  ['Supergiant Games']  A rogue-lite hack and slash dungeon crawler in...
# 3       ['Team Cherry']  A 2D metroidvania with an emphasis on close co...
# 4            ['tobyfox'  A small child falls into the Underground, wher...
#
#                                            Platforms  \
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 1                       ['Wii U', 'Nintendo Switch']
# 2  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 3  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch']
# 4  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'...
#
#                                               Genres  Rating Plays Playing  \
# 0                               ['Adventure', 'RPG']     4.5   21K    4.1K
# 1                            ['Adventure', 'Puzzle']     4.4   35K    3.1K
# 2           ['Adventure', 'Brawler', 'Indie', 'RPG']     4.3   25K    3.5K
# 3                 ['Adventure', 'Indie', 'Platform']     4.4   25K    2.7K
# 4  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...     4.2   32K     728
#
#   Backlogs Wishlist Lists Reviews
# 0     5.6K     5.5K  4.6K      3K
# 1     5.6K       3K  5.1K      3K
# 2     7.3K       4K  3.2K    2.1K
# 3     9.6K     2.6K  3.4K    2.1K
# 4     5.7K     2.1K  3.9K    2.5K

# %%
game_df["Developers"] = game_df["Developers"].astype(str)
game_df.head()
# Out:
#    Unnamed: 0                                    Title  Release_Date  \
# 0           0                               Elden Ring  Feb 25, 2022
# 1           1  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2           2                                    Hades  Dec 07, 2018
# 3           3                            Hollow Knight  Feb 24, 2017
# 4           4                                Undertale  Sep 15, 2015
#
#              Developers                                            Summary  \
# 0       ['FromSoftware'  Elden Ring is a fantasy, action and open world...
# 1           ['Nintendo'  The Legend of Zelda: Breath of the Wild is the...
# 2  ['Supergiant Games']  A rogue-lite hack and slash dungeon crawler in...
# 3       ['Team Cherry']  A 2D metroidvania with an emphasis on close co...
# 4            ['tobyfox'  A small child falls into the Underground, wher...
#
#                                            Platforms  \
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 1                       ['Wii U', 'Nintendo Switch']
# 2  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 3  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch']
# 4  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'...
#
#                                               Genres  Rating Plays Playing  \
# 0                               ['Adventure', 'RPG']     4.5   21K    4.1K
# 1                            ['Adventure', 'Puzzle']     4.4   35K    3.1K
# 2           ['Adventure', 'Brawler', 'Indie', 'RPG']     4.3   25K    3.5K
# 3                 ['Adventure', 'Indie', 'Platform']     4.4   25K    2.7K
# 4  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...     4.2   32K     728
#
#   Backlogs Wishlist Lists Reviews
# 0     5.6K     5.5K  4.6K      3K
# 1     5.6K       3K  5.1K      3K
# 2     7.3K       4K  3.2K    2.1K
# 3     9.6K     2.6K  3.4K    2.1K
# 4     5.7K     2.1K  3.9K    2.5K

# %%
game_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    60000 non-null  int64
#  1   Title         60000 non-null  object
#  2   Release_Date  60000 non-null  object
#  3   Developers    60000 non-null  object
#  4   Summary       55046 non-null  object
#  5   Platforms     60000 non-null  object
#  6   Genres        60000 non-null  object
#  7   Rating        25405 non-null  float64
#  8   Plays         60000 non-null  object
#  9   Playing       60000 non-null  object
#  10  Backlogs      60000 non-null  object
#  11  Wishlist      60000 non-null  object
#  12  Lists         60000 non-null  object
#  13  Reviews       60000 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 6.4+ MB

# %%
game_df["Developers"] = game_df["Developers"].apply(lambda x: str(x).lstrip("['"))
game_df["Developers"] = game_df["Developers"].apply(lambda x: str(x).rstrip("']"))
game_df.head()
# Out:
#    Unnamed: 0                                    Title Release_Date  \
# 0           0                               Elden Ring   2022-02-25
# 1           1  The Legend of Zelda: Breath of the Wild   2017-03-03
# 2           2                                    Hades   2018-12-07
# 3           3                            Hollow Knight   2017-02-24
# 4           4                                Undertale   2015-09-15
#
#          Developers                                            Summary  \
# 0      FromSoftware  Elden Ring is a fantasy, action and open world...
# 1          Nintendo  The Legend of Zelda: Breath of the Wild is the...
# 2  Supergiant Games  A rogue-lite hack and slash dungeon crawler in...
# 3       Team Cherry  A 2D metroidvania with an emphasis on close co...
# 4           tobyfox  A small child falls into the Underground, wher...
#
#                                            Platforms  \
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 1                       ['Wii U', 'Nintendo Switch']
# 2  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 3  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch']
# 4  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'...
#
#                                               Genres  Rating  Plays  Playing  \
# 0                               ['Adventure', 'RPG']     4.5  21000     4100
# 1                            ['Adventure', 'Puzzle']     4.4  35000     3100
# 2           ['Adventure', 'Brawler', 'Indie', 'RPG']     4.3  25000     3500
# 3                 ['Adventure', 'Indie', 'Platform']     4.4  25000     2700
# 4  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...     4.2  32000   728000
#
#    Backlogs  Wishlist  Lists  Reviews
# 0      5600      5500   4600     3000
# 1      5600      3000   5100     3000
# 2      7300      4000   3200     2100
# 3      9600      2600   3400     2100
# 4      5700      2100   3900     2500

# %%
game_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    60000 non-null  int64
#  1   Title         60000 non-null  object
#  2   Release_Date  60000 non-null  object
#  3   Developers    60000 non-null  object
#  4   Summary       55046 non-null  object
#  5   Platforms     60000 non-null  object
#  6   Genres        60000 non-null  object
#  7   Rating        25405 non-null  float64
#  8   Plays         60000 non-null  object
#  9   Playing       60000 non-null  object
#  10  Backlogs      60000 non-null  object
#  11  Wishlist      60000 non-null  object
#  12  Lists         60000 non-null  object
#  13  Reviews       60000 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 6.4+ MB

# %%
# Use a for loop to change to columns (Plays, Playing, Backlogs, Wishlist, Lists, and Reviews)
# Use an replace statement to any change any value with 'K' to a float, multiply that by 1,000, and then change the entire column to integers

cols = ('Plays', 'Playing', 'Backlogs', 'Wishlist', 'Lists', 'Reviews')

for col in cols:
   game_df[col] = (game_df[col].str.replace('K', '').astype(float)*1000).astype(int)

game_df.head()
# Out:
#    Unnamed: 0                                    Title  Release_Date  \
# 0           0                               Elden Ring  Feb 25, 2022
# 1           1  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2           2                                    Hades  Dec 07, 2018
# 3           3                            Hollow Knight  Feb 24, 2017
# 4           4                                Undertale  Sep 15, 2015
#
#             Developers                                            Summary  \
# 0       'FromSoftware'  Elden Ring is a fantasy, action and open world...
# 1           'Nintendo'  The Legend of Zelda: Breath of the Wild is the...
# 2  'Supergiant Games']  A rogue-lite hack and slash dungeon crawler in...
# 3       'Team Cherry']  A 2D metroidvania with an emphasis on close co...
# 4            'tobyfox'  A small child falls into the Underground, wher...
#
#                                            Platforms  \
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 1                       ['Wii U', 'Nintendo Switch']
# 2  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 3  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch']
# 4  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'...
#
#                                               Genres  Rating  Plays  Playing  \
# 0                               ['Adventure', 'RPG']     4.5  21000     4100
# 1                            ['Adventure', 'Puzzle']     4.4  35000     3100
# 2           ['Adventure', 'Brawler', 'Indie', 'RPG']     4.3  25000     3500
# 3                 ['Adventure', 'Indie', 'Platform']     4.4  25000     2700
# 4  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...     4.2  32000   728000
#
#    Backlogs  Wishlist  Lists  Reviews
# 0      5600      5500   4600     3000
# 1      5600      3000   5100     3000
# 2      7300      4000   3200     2100
# 3      9600      2600   3400     2100
# 4      5700      2100   3900     2500

# %%
# Change Release_Date to datetime, had to adjust for TBD values so changed them to NaT (Not a Time) function

game_df['Release_Date'] = game_df['Release_Date'].str.replace('TBD', 'NaT')
game_df['Release_Date'] = pd.to_datetime(game_df['Release_Date'])

# %%
game_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    60000 non-null  int64
#  1   Title         60000 non-null  object
#  2   Release_Date  51981 non-null  datetime64[ns]
#  3   Developers    60000 non-null  object
#  4   Summary       55046 non-null  object
#  5   Platforms     60000 non-null  object
#  6   Genres        60000 non-null  object
#  7   Rating        25405 non-null  float64
#  8   Plays         60000 non-null  int32
#  9   Playing       60000 non-null  int32
#  10  Backlogs      60000 non-null  int32
#  11  Wishlist      60000 non-null  int32
#  12  Lists         60000 non-null  int32
#  13  Reviews       60000 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(6), int64(1), object(5)
# memory usage: 5.0+ MB
